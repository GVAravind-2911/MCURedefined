# %%
import sqlalchemy
from sqlalchemy import ForeignKey, Column, String
from sqlalchemy.orm import sessionmaker, declarative_base, relationship

AUTHTOKEN = "eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicm8iLCJpYXQiOjE3MzMwMzUyMzUsImlkIjoiNGJmNzQ1NTAtYTQ0Ni00NjM3LWJlNDctZTJhOWZkNzM3MzIyIn0.KFqB-EnvjtVFcuO389vtTfbZ-7ZdQJrTQxTpBAf1J2p7AC5hA1w0n1LrjZnQP5eakhFXXAIYroZ4ShVDtsvHCQ"

Base = declarative_base()

class Departments(Base):
    __tablename__ = 'Departments'
    departmentCode = Column(String(10), primary_key=True)
    departmentName = Column(String(255))

    students = relationship("Student", back_populates="department")

    def to_dict(self):
        return {
            'departmentCode': self.departmentCode,
            'departmentName': self.departmentName
        }
    
    @staticmethod
    def get_data():
        engine = sqlalchemy.create_engine(f'sqlite+libsql://studentcodingplatforms-varunchowdary0.turso.io/?authToken={AUTHTOKEN}')
        session = sessionmaker(bind=engine)()
        departments = session.query(Departments).all()
        data = [department.to_dict() for department in departments]
        print(data)
        return data


class Student(Base):
    __tablename__ = 'Student_Data'
    RollNumber = Column(String(10), primary_key=True)
    Name = Column(String(255))
    Department = Column(String(10), ForeignKey('Departments.departmentCode'))

    department = relationship("Departments", back_populates="students")
    user = relationship("Users", back_populates="student")


class Users(Base):
    __tablename__ = 'Users'
    RollNumber = Column(String(10), ForeignKey('Student_Data.RollNumber'), primary_key=True)
    password = Column(String(255))
    
    student = relationship("Student", back_populates="user")

    def to_dict(self):
        return {
            'RollNumber': self.RollNumber,
            'password': self.password,
            'student': {
                'Name': self.student.Name,
                'Department': self.student.Department
            }
        }

    @staticmethod
    def get_data():
        engine = sqlalchemy.create_engine(f'sqlite+libsql://studentcodingplatforms-varunchowdary0.turso.io/?authToken={AUTHTOKEN}')
        session = sessionmaker(bind=engine)()
        users = session.query(Users).all()
        data = [user.to_dict() for user in users]
        print(data)
        return data

# Main block to fetch roll numbers from Users table
if __name__ == "__main__":
    users_data = Users.get_data()
    roll_numbers = [user['RollNumber'] for user in users_data]
    print("Roll Numbers:", roll_numbers)
# Out:
# ---------------------------------------------------------------------------
# LibsqlError                               Traceback (most recent call last)
# File d:\Programming\Projects\MCURedefined\backend\MCURedefined\Lib\site-packages\libsql_client\dbapi2\hrana.py:366, in CursorHrana._raw_execute_one(self, stmt)
#     365     self.connection._trace(stmt["sql"])
# --> 366 result = self.connection._raw_execute(stmt)
#     367 return _conv_stmt_result(result, None)
#
# File d:\Programming\Projects\MCURedefined\backend\MCURedefined\Lib\site-packages\libsql_client\dbapi2\hrana.py:214, in run_in_executor.<locals>.wrapper(*args, **kwargs)
#     212 future = self._executor.submit(fn, *args, **kwargs)
# --> 214 return future.result(timeout=self._timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# ...
